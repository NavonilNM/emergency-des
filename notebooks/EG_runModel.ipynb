# %%
# %load_ext autoreload
# %autoreload 2

from simulation.eg_parameters import Parameters
from simulation.eg_runner import Runner
#from simulation.eg_model import Model
import os


# This part of the code is for the section RAP - Output Analysis - Performance measures
runner = Runner(param=Parameters())
result = runner.run_single(run=0)
#print(result["patient"])
result["patient"]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#    patient_id period  arrival_time  wait_time  time_with_doctor   end_time  \
# 0           1   🔹 DC     37.778250   0.000000         19.610317  57.388567
# 1           2   🔹 DC     38.108184   0.000000          9.489737  47.597921
# 2           3   🔹 DC     42.610666   4.987255         41.665475        NaN
# 3           4   🔹 DC     44.087985  12.574406          5.874479  62.536870
# 4           5   🔹 DC     55.587763   1.800804         27.882444        NaN
# 5           6   🔹 DC     64.880007   0.000000         24.914615        NaN
# 6           7   🔹 DC     64.954293        NaN               NaN        NaN
#
#    run  time_in_system  unseen_wait_time
# 0    0       19.610317               NaN
# 1    0        9.489737               NaN
# 2    0             NaN               NaN
# 3    0       18.448885               NaN
# 4    0             NaN               NaN
# 5    0             NaN               NaN
# 6    0             NaN          5.045707

# %%
print(result["run"])
# Out:
# {'run_number': 0, 'arrivals': 7, 'mean_wait_time': np.float64(3.227077467801481), 'mean_time_with_doctor': np.float64(21.57284454497007), 'mean_utilisation': 0.8743911437929205, 'mean_time_in_system': np.float64(15.849646506571181), 'mean_patients_in_system': 3.2333777169670244, 'unseen_count': np.int64(1), 'unseen_wait_time': np.float64(5.045706616721617)}
