# %%
# %load_ext autoreload
# %autoreload 2

from simulation.eg_parameters import Parameters
from simulation.eg_runner import Runner
#from simulation.eg_model import Model
import os


# This part of the code is for the section RAP - Output Analysis - Performance measures
runner = Runner(param=Parameters())
result = runner.run_single(run=0)
print(result["patient"])
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#    patient_id period  arrival_time  wait_time  time_with_doctor  run
# 0           1   🔹 DC     37.778250   0.000000         19.610317    0
# 1           2   🔹 DC     38.108184   0.000000          9.489737    0
# 2           3   🔹 DC     42.610666   4.987255         41.665475    0
# 3           4   🔹 DC     44.087985  12.574406          5.874479    0
# 4           5   🔹 DC     55.587763   1.800804         27.882444    0
# 5           6   🔹 DC     64.880007   0.000000         24.914615    0
# 6           7   🔹 DC     64.954293        NaN               NaN    0

# %%
print(result["run"])
# Out:
# {'run_number': 0, 'arrivals': 7, 'mean_wait_time': np.float64(3.227077467801481), 'mean_time_with_doctor': np.float64(21.57284454497007), 'mean_utilisation': 0.8743911437929205}
