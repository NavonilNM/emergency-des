# %%
# %load_ext autoreload
# %autoreload 2

from simulation.eg_parameters import Parameters
from simulation.eg_runner_usingMonitoredResource import RunnerMR
#from simulation.eg_model import Model
import os
from IPython.display import HTML
from itables import to_html_datatable


# This part of the code is for the section RAP - Output Analysis - Performance measures
# runner = RunnerMR(param=Parameters())
# result = runner.run_single(run=0)
# print(result["patient"])

#This is for replication - Performance measures
runner = RunnerMR(param=Parameters())
result = runner.run_reps()
HTML(to_html_datatable(result["patient"]))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <!--| quarto-html-table-processing: none -->
# <table id="itables_8f7b7a06_0c89_46af_9488_260dfe24ad5b"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
# ...

# %%
HTML(to_html_datatable(result["run"]))
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_af723079_70c0_4714_943d_068d7f10f54b"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
# ...

# %%
HTML(to_html_datatable(result["overall"]))
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_07a1b63a_c3d1_48a9_9b9d_4c00558fe88c"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
# ...

# %%
print(result["run"])
# Out:
# {'run_number': 0, 'arrivals': 7, 'mean_wait_time': np.float64(3.227077467801481), 'mean_time_with_doctor': np.float64(21.57284454497007), 'mean_utilisation_tw': 0.8743911437929205, 'mean_queue_length': 0.6102042855882626}

# %%
import time
import pandas as pd


speed = []

# Run for 1 to 4 cores
for i in range(1, 5):
    # Start timer and run replications
    start_time = time.time()
    experiment = RunnerMR(param = Parameters(cores=i))
    experiment.run_reps()
    # Find run time
    run_time = time.time() - start_time
    speed.append({"cores": i, "run_time": run_time})

# Convert times to dataframe
timing_results = pd.DataFrame(speed)
HTML(to_html_datatable((timing_results)))
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_a2e963ac_e292_4cf8_af35_25fe4542539f"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
# ...

# %%
import plotly.express as px
# Plot time by number of cores
fig = px.line(timing_results, x="cores", y="run_time")
fig.update_layout(
    xaxis={"dtick": 1},
    xaxis_title="Number of cores",
    yaxis_title="Run time",
    template="plotly_white"
)
